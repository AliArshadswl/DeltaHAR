# %%
# !CUDA_VISIBLE_DEVICES=2 python Real_world_fold_wise.py
# Out:
# Device: cuda
#   GPU: NVIDIA H800 PCIe
# ...
#   PatchHAR v2  --  RealWorld2016  --  5-Fold Subject-Wise CV (7:1:2)
#   D_MODEL=56 | N_HEADS=4 | N_LAYERS=4 | N_EXPERTS=4
#   Window=500 samples | Patch lens=[25, 50, 100] | Channels=9
#   Active contributions:
# ...
#
# Loading RealWorld2016 dataset ...
#   Loading 120/120  windows so far: 11857
#   Total windows: 11857
#
# ...
#   FOLD 1/5
#   Train subjects (10): ['proband9', 'proband3', 'proband2', 'proband15', 'proband5', 'proband8', 'proband11', 'proband13', 'proband4', 'proband7']
#   Val   subjects (2):   ['proband14', 'proband6']
#   Test  subjects (3):  ['proband10', 'proband12', 'proband1']
#   Windows  train:7977  val:1366  test:2514
#   Parameters: 363,131
#     Ep 001/120 | F1=0.0855 | kappa=0.0503
#     Ep 002/120 | F1=0.4030 | kappa=0.3614
#     Ep 003/120 | F1=0.6600 | kappa=0.6667
#     Ep 004/120 | F1=0.7408 | kappa=0.7368
#     Ep 005/120 | F1=0.8358 | kappa=0.8356
#     Ep 006/120 | F1=0.8841 | kappa=0.8751
# ...
