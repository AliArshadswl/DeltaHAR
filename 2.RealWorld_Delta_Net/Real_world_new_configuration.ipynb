# %%
# !CUDA_VISIBLE_DEVICES=2 python Real_world_different_configuration.py
# Out:
# Device: cuda
#   GPU: NVIDIA H800 PCIe
# ...
#   PatchHAR v2  —  RealWorld2016  —  LOGO CV
#   D_MODEL=56 | N_HEADS=4 | N_LAYERS=4 | N_EXPERTS=4
#   Window=500 samples | Patch lens=[25, 50, 100] | Channels=9
#   Active contributions:
# ...
#
# Loading RealWorld2016 dataset ...
#   Loading 120/120  windows so far: 11857
#   Total windows: 11857
#
# ...
#   FOLD 1/15  test=proband1  val=proband2  train=['p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9', 'p10', 'p11', 'p12', 'p13', 'p14', 'p15']
#   Windows  train:10249  val:762  test:846
#   Parameters: 363,131
#     Ep 001/120 | F1=0.1378 | kappa=0.1214
#     Ep 002/120 | F1=0.5686 | kappa=0.5452
#     Ep 003/120 | F1=0.7385 | kappa=0.7174
#     Ep 004/120 | F1=0.7595 | kappa=0.7318
#     Ep 005/120 | F1=0.7791 | kappa=0.7421
#     Ep 006/120 | F1=0.8021 | kappa=0.7619
#     Ep 007/120 | F1=0.7958 | kappa=0.7651
#     Ep 008/120 | F1=0.7926 | kappa=0.7621
#     Ep 009/120 | F1=0.8105 | kappa=0.7835
#     Ep 010/120 | F1=0.8122 | kappa=0.7773
# ...
