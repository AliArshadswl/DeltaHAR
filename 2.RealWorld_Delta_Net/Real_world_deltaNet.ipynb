# %%
# !CUDA_VISIBLE_DEVICES=2 python Real_World_Delta_Net.py
# Out:
# Device: cuda
#   GPU: NVIDIA H800 PCIe
# ...
#   PatchHAR v2  —  RealWorld2016  —  LOGO CV
#   D_MODEL=64 | N_HEADS=2 | N_LAYERS=3 | N_EXPERTS=4
#   Window=500 samples | Patch lens=[25, 50, 100] | Channels=9
#   Active contributions:
# ...
#
# Loading RealWorld2016 dataset ...
#   Loading 120/120  windows so far: 11858
#   Total windows: 11858
#
# ...
#   FOLD 1/15  test=proband1  val=proband2  train=['p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9', 'p10', 'p11', 'p12', 'p13', 'p14', 'p15']
#   Windows  train:10250  val:762  test:846
#   Parameters: 423,694
#     Ep 001/120 | F1=0.0783 | kappa=0.0915
#     Ep 002/120 | F1=0.3565 | kappa=0.2888
#     Ep 003/120 | F1=0.5099 | kappa=0.4550
#     Ep 004/120 | F1=0.6881 | kappa=0.6563
#     Ep 005/120 | F1=0.7230 | kappa=0.6986
#     Ep 006/120 | F1=0.7457 | kappa=0.7229
#     Ep 007/120 | F1=0.7686 | kappa=0.7487
#     Ep 008/120 | F1=0.7662 | kappa=0.7428
#     Ep 009/120 | F1=0.7562 | kappa=0.7325
#     Ep 010/120 | F1=0.7249 | kappa=0.6973
# ...

# %%
56
4
4
0.3
