# %%
# !CUDA_VISIBLE_DEVICES=2 python Real_world_corrected.py
# Out:
# Device: cuda
#   GPU: NVIDIA H800 PCIe
# ...
#   PatchHAR v2  —  RealWorld2016  —  LOGO CV
#   D_MODEL=64 | N_HEADS=2 | N_LAYERS=3 | N_EXPERTS=4
#   Window=500 samples | Patch lens=[25, 50, 100] | Channels=9
#   Active contributions:
# ...
#
# Loading RealWorld2016 dataset ...
#   Loading 120/120  windows so far: 11857
#   Total windows: 11857
#
# ...
#   FOLD 1/15  test=proband1  val=proband2  train=['p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9', 'p10', 'p11', 'p12', 'p13', 'p14', 'p15']
#   Windows  train:10249  val:762  test:846
#   Parameters: 423,694
#     Ep 001/120 | F1=0.0702 | kappa=0.0863
#     Ep 002/120 | F1=0.3668 | kappa=0.3104
#     Ep 003/120 | F1=0.5410 | kappa=0.4989
#     Ep 004/120 | F1=0.6761 | kappa=0.6401
#     Ep 005/120 | F1=0.7227 | kappa=0.7050
#     Ep 006/120 | F1=0.7387 | kappa=0.7154
#     Ep 007/120 | F1=0.7648 | kappa=0.7350
#     Ep 008/120 | F1=0.7766 | kappa=0.7408
#     Ep 009/120 | F1=0.7833 | kappa=0.7453
#     Ep 010/120 | F1=0.7936 | kappa=0.7575
# ...
