# %%
# !CUDA_VISIBLE_DEVICES=1 python Interpretability.py
# Out:
# Device : cuda
# GPU    : NVIDIA H800 PCIe
# Discovered 151 participants, 4 classes: ['light', 'moderate-vigorous', 'sedentary', 'sleep']
# Split  : train=80 | val=20 | test=51
# Checkpoint : /mnt/share/ali/processed/patchhar_results/weights_patchhar_v2.pth
# Output dir : /mnt/share/ali/processed/patchhar_results/interp
# Methods    : ['I1', 'I2', 'I3', 'I4', 'I5', 'I6', 'I7', 'I8']
# N samples  : 500
# ...
#   PatchHAR v2 — Interpretability Analysis
# ...
#   Loaded: weights_patchhar_v2.pth
#   Active contributions:
#   Loaded 10/51 subjects — 39,337 windows
#   Loaded 20/51 subjects — 75,982 windows
#   Loaded 30/51 subjects — 117,302 windows
#   Loaded 40/51 subjects — 153,910 windows
#   Loaded 50/51 subjects — 191,986 windows
#   Loaded 51/51 subjects — 196,063 windows
#
# ── I1: Attention head maps ──
#   Saved: I1_attention_maps.pdf / .png
#
# ── I2: Gradient x input saliency ──
#   Saved: I2_gradient_saliency.pdf / .png
#   Saved: I2_gradient_saliency_per_axis.pdf / .png
#
# ...
