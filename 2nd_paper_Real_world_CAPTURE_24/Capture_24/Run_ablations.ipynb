# %%
# !CUDA_VISIBLE_DEVICES=2 python run_ablations.py
# Out:
# ...
#   PatchHAR v2 — Ablation Runner
#   Script : patchhar_v2.py
#   Seeds  : [42, 123, 456]
#   Configs: 12  (36 total runs)
# ...
#   Output dir : /mnt/share/ali/processed/patchhar_results
#
#   [1/36] full_s42
#
# ──────────────────────────────────────────────────────────────────────
#   RUN : full_s42
#   CMD : /opt/anaconda3/envs/jupyterhub4/bin/python patchhar_v2.py --run-id full_s42 --seed 42
# ──────────────────────────────────────────────────────────────────────
# Device : cuda
# GPU    : NVIDIA H800 PCIe
# Discovered 151 participants, 4 classes: ['light', 'moderate-vigorous', 'sedentary', 'sleep']
# Split  : train=80 | val=20 | test=51
# ...
#   PatchHAR v2
#   D_MODEL=64 | N_LAYERS=3 | N_HEADS=2 | N_EXPERTS=4
#   Device : cuda
#   Output : /mnt/share/ali/processed/patchhar_results
#
#   Active contributions:
# ...
#
# ── Loading data ──
#   Loaded 10/80 subjects — 40,369 windows
#   Loaded 20/80 subjects — 79,016 windows
