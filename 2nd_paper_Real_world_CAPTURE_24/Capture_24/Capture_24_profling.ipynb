# %%
# !CUDA_VISIBLE_DEVICES=1 python Capture_24_profiling.py
# Out:
# Device : cuda
# GPU    : NVIDIA H800 PCIe
# Discovered 151 participants, 4 classes: ['light', 'moderate-vigorous', 'sedentary', 'sleep']
# Split  : train=80 | val=20 | test=51
# Device : cuda
# GPU    : NVIDIA H800 PCIe
#
#   NOTE: No valid checkpoint provided — random weights (latency/complexity still valid).
#
# ── MODEL COMPLEXITY ─────────────────────────────────────────────
#   total_params                : 1970776
#   trainable_params            : 1970776
#   buffer_params               : 2176
#   size_fp32_mb                : 7.95
#   size_fp16_mb                : 4.0
#   flops_gflops                : 0.0648
#   d_model                     : 64
#   n_heads                     : 2
#   n_layers                    : 3
#   n_experts                   : 4
#   n_patches                   : 120
#   patch_len                   : 25
#   window_size                 : 3000
#   signal_rate                 : 100
#   channels                    : 3
#   num_classes                 : 4
# ...
