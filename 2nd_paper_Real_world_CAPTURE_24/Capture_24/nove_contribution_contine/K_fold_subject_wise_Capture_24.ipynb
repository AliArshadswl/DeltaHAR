# %%
# !CUDA_VISIBLE_DEVICES=1 python K_fold_subject_wise_Capture_24.py
# Out:
# Device : cuda
# GPU    : NVIDIA H800 PCIe
# Discovered 151 participants, 4 classes: ['light', 'moderate-vigorous', 'sedentary', 'sleep']
#
# ── Building CV folds ──
#   Fold 0: train=105 | val= 16 | test= 30  (ratio ≈ 0.70:0.11:0.20)
#   Fold 1: train=105 | val= 16 | test= 30  (ratio ≈ 0.70:0.11:0.20)
#   Fold 2: train=105 | val= 15 | test= 31  (ratio ≈ 0.70:0.10:0.21)
#   Fold 3: train=105 | val= 16 | test= 30  (ratio ≈ 0.70:0.11:0.20)
#   Fold 4: train=105 | val= 16 | test= 30  (ratio ≈ 0.70:0.11:0.20)
# ...
#   PatchHAR v3 — 5-Fold Subject-wise Cross-Validation (7:1:2)
#   D_MODEL=64 | N_LAYERS=3 | N_HEADS=2 | N_EXPERTS=4
#   N_FOLDS=5  |  Device=cuda
#   Output : /mnt/share/ali/processed/patchhar_results
#
#   Active contributions:
# ...
#
# ──────────────────────────────────────────────────────────────────────
#   FOLD 0  |  train=105  val=16  test=30
# ──────────────────────────────────────────────────────────────────────
#   Loading training data (fold 0) …
# ...
