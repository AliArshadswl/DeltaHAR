# %%
# !CUDA_VISIBLE_DEVICES=2 python patchhar_interpretability.py
# Out:
# [INFO] umap-learn not found – using t-SNE for embeddings.
# Device : cuda
# GPU    : NVIDIA H800 PCIe
# Discovered 151 participants, 4 classes: ['light', 'moderate-vigorous', 'sedentary', 'sleep']
# Split  : train=80 | val=20 | test=51
# ...
#   PatchHAR v2 — Interpretability Suite
#   Output : /mnt/share/ali/processed/patchhar_results/interpretability
# ...
# [✓] Loaded checkpoint: /mnt/share/ali/processed/patchhar_results/weights_patchhar_v2.pth
#   Loaded 10/51 subjects — 39,337 windows
#   Loaded 20/51 subjects — 75,982 windows
#   Loaded 30/51 subjects — 117,302 windows
#   Loaded 40/51 subjects — 153,910 windows
#   Loaded 50/51 subjects — 191,986 windows
#   Loaded 51/51 subjects — 196,063 windows
#   Loaded 10/20 subjects — 37,556 windows
#   Loaded 20/20 subjects — 78,196 windows
#
# [*] Collecting model outputs on test set …
#     N=196,063 samples  |  Macro-F1=0.7755  (60s)
#    [cache] outputs saved → /mnt/share/ali/processed/patchhar_results/interpretability/_outputs_cache.npz
#
# ...

# %%
# !CUDA_VISIBLE_DEVICES=2 python interpretability_v1.py
# Out:
# [INFO] umap-learn not found – using t-SNE for embeddings.
# Device : cuda
# GPU    : NVIDIA H800 PCIe
# Discovered 151 participants, 4 classes: ['light', 'moderate-vigorous', 'sedentary', 'sleep']
# Split  : train=80 | val=20 | test=51
# [Style] Font selected: 'Liberation Serif'
# ...
#   PatchHAR v2 — Interpretability Suite
#   Output : /mnt/share/ali/processed/patchhar_results/interpretability
# ...
# [✓] Loaded checkpoint: /mnt/share/ali/processed/patchhar_results/weights_patchhar_v2.pth
#   Loaded 10/51 subjects — 39,337 windows
#   Loaded 20/51 subjects — 75,982 windows
#   Loaded 30/51 subjects — 117,302 windows
#   Loaded 40/51 subjects — 153,910 windows
#   Loaded 50/51 subjects — 191,986 windows
#   Loaded 51/51 subjects — 196,063 windows
#   Loaded 10/20 subjects — 37,556 windows
#   Loaded 20/20 subjects — 78,196 windows
#
# [*] Collecting model outputs on test set …
#     N=196,063 samples  |  Macro-F1=0.7755  (63s)
# ...
