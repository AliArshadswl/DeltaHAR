# %%
# !CUDA_VISIBLE_DEVICES=0 python Interpretability_C5_FREQ_AUGMENTATION.py      ######C5_FREQ_AUGMENTATION       = False   # band-pass / axis-perm / warp
# Out:
# Device : cuda
# GPU    : NVIDIA H800 PCIe
# Discovered 151 participants, 4 classes: ['light', 'moderate-vigorous', 'sedentary', 'sleep']
# Split  : train=80 | val=20 | test=51
# ======================================================================
#   PatchHAR v2
#   D_MODEL=64 | N_LAYERS=3 | N_HEADS=2 | N_EXPERTS=4
#   Device : cuda
#   Output : /mnt/share/ali/processed/patchhar_results
#
#   Active contributions:
#
#   [C4] Hierarchical patch embedding:
#     fine    25-sample patches → 120 tokens
#     mid     50-sample patches → 60 tokens → repeat×2 → 120 tokens
#     coarse 100-sample patches → 30 tokens → repeat×4 → 120 tokens
#     fusion : token_i = fine_i + mid_{i//2} + coarse_{i//4}
# ======================================================================
#
# ── Loading data ──
#   Loaded 10/80 subjects — 40,369 windows
#   Loaded 20/80 subjects — 79,016 windows
#   Loaded 30/80 subjects — 121,579 windows
#   Loaded 40/80 subjects — 160,857 windows
#   Loaded 50/80 subjects — 198,881 windows
#   Loaded 60/80 subjects — 240,108 windows
#   Loaded 70/80 subjects — 280,805 windows
#   Loaded 80/80 subjects — 321,381 windows
#   Loaded 10/20 subjects — 37,556 windows
#   Loaded 20/20 subjects — 78,196 windows
#   Loaded 10/51 subjects — 39,337 windows
#   Loaded 20/51 subjects — 75,982 windows
#   Loaded 30/51 subjects — 117,302 windows
#   Loaded 40/51 subjects — 153,910 windows
#   Loaded 50/51 subjects — 191,986 windows
#   Loaded 51/51 subjects — 196,063 windows
#   Train 321,381 | Val 78,196 | Test 196,063
#
#   Parameters : 1,940,760
#
# ── Training ──
#   Epoch 01/30 | lr=2.80e-04 | loss=0.6026 | F1=0.6796 | κ=0.6735
#     ✓ Checkpoint saved  (F1=0.6796)
#   Epoch 02/30 | lr=7.60e-04 | loss=0.5697 | F1=0.7167 | κ=0.7375
#     ✓ Checkpoint saved  (F1=0.7167)
#   Epoch 03/30 | lr=1.00e-03 | loss=0.5614 | F1=0.7115 | κ=0.7262
#   Epoch 04/30 | lr=9.97e-04 | loss=0.5538 | F1=0.7413 | κ=0.7520
#     ✓ Checkpoint saved  (F1=0.7413)
#   Epoch 05/30 | lr=9.87e-04 | loss=0.5486 | F1=0.7408 | κ=0.7707
#     ✓ Checkpoint saved  (F1=0.7408)
#   Epoch 06/30 | lr=9.70e-04 | loss=0.5462 | F1=0.7443 | κ=0.7622
#   Epoch 07/30 | lr=9.47e-04 | loss=0.5429 | F1=0.7433 | κ=0.7581
#   Epoch 08/30 | lr=9.18e-04 | loss=0.5402 | F1=0.7594 | κ=0.7799
#     ✓ Checkpoint saved  (F1=0.7594)
#   Epoch 09/30 | lr=8.83e-04 | loss=0.5372 | F1=0.7440 | κ=0.7601
#   Epoch 10/30 | lr=8.43e-04 | loss=0.5361 | F1=0.7505 | κ=0.7664
#   Epoch 11/30 | lr=7.99e-04 | loss=0.5325 | F1=0.7565 | κ=0.7627
#   Epoch 12/30 | lr=7.50e-04 | loss=0.5312 | F1=0.7707 | κ=0.7789
#     ✓ Checkpoint saved  (F1=0.7707)
#   Epoch 13/30 | lr=6.98e-04 | loss=0.5295 | F1=0.7548 | κ=0.7615
#   Epoch 14/30 | lr=6.43e-04 | loss=0.5261 | F1=0.7471 | κ=0.7637
#   Epoch 15/30 | lr=5.87e-04 | loss=0.5251 | F1=0.7614 | κ=0.7805
#   Epoch 16/30 | lr=5.29e-04 | loss=0.5225 | F1=0.7573 | κ=0.7727
#   Epoch 17/30 | lr=4.71e-04 | loss=0.5203 | F1=0.7660 | κ=0.7853
#     ✓ Checkpoint saved  (F1=0.7660)
#   Epoch 18/30 | lr=4.13e-04 | loss=0.5183 | F1=0.7588 | κ=0.7759
#   Epoch 19/30 | lr=3.57e-04 | loss=0.5165 | F1=0.7545 | κ=0.7672
#   Epoch 20/30 | lr=3.02e-04 | loss=0.5150 | F1=0.7626 | κ=0.7765
#   Epoch 21/30 | lr=2.50e-04 | loss=0.5124 | F1=0.7614 | κ=0.7802
#   Epoch 22/30 | lr=2.01e-04 | loss=0.5104 | F1=0.7663 | κ=0.7832
#   Epoch 23/30 | lr=1.57e-04 | loss=0.5093 | F1=0.7712 | κ=0.7876
#     ✓ Checkpoint saved  (F1=0.7712)
#   Epoch 24/30 | lr=1.17e-04 | loss=0.5077 | F1=0.7664 | κ=0.7870
#   Epoch 25/30 | lr=8.23e-05 | loss=0.5070 | F1=0.7628 | κ=0.7817
#   Epoch 26/30 | lr=5.32e-05 | loss=0.5048 | F1=0.7666 | κ=0.7848
#   Epoch 27/30 | lr=3.02e-05 | loss=0.5047 | F1=0.7688 | κ=0.7830
#   Epoch 28/30 | lr=1.35e-05 | loss=0.5039 | F1=0.7692 | κ=0.7849
#   Epoch 29/30 | lr=3.38e-06 | loss=0.5032 | F1=0.7692 | κ=0.7851
#   Epoch 30/30 | lr=4.00e-09 | loss=0.5037 | F1=0.7691 | κ=0.7849
#   Best checkpoint loaded from /mnt/share/ali/processed/patchhar_results/weights_patchhar_v2.pth
#
# ── Evaluation ──
#
#   Macro-F1 = 0.7483 | κ = 0.7658 | MCC = 0.7671 | Acc = 0.8395
#
#                    precision    recall  f1-score   support
#
#             light       0.63      0.72      0.67     37797
# moderate-vigorous       0.49      0.50      0.50     11751
#         sedentary       0.89      0.80      0.84     73061
#             sleep       0.98      0.99      0.98     73454
#
#          accuracy                           0.84    196063
#         macro avg       0.75      0.75      0.75    196063
#      weighted avg       0.85      0.84      0.84    196063
#
#
#   Results saved: /mnt/share/ali/processed/patchhar_results/patchhar_v2_results.json
# ======================================================================
#   DONE
# ======================================================================
