# %%
# !CUDA_VISIBLE_DEVICES=2 python ablation_3_self_attention.py
# Out:
#   [Ablation 3] GDN → self-attention  (all other components kept)
# Device : cuda
# Discovered 151 participants, 4 classes: ['light', 'moderate-vigorous', 'sedentary', 'sleep']
# Split  : train=80 | val=20 | test=51
# ...
#   PatchHAR v2 — Ablation 3: GDN → Standard Self-Attention
# ...
#   Loaded 10/80 — 40,369 windows
#   Loaded 20/80 — 79,016 windows
#   Loaded 30/80 — 121,579 windows
#   Loaded 40/80 — 160,857 windows
#   Loaded 50/80 — 198,881 windows
#   Loaded 60/80 — 240,108 windows
#   Loaded 70/80 — 280,805 windows
#   Loaded 80/80 — 321,381 windows
#   Loaded 10/20 — 37,556 windows
#   Loaded 20/20 — 78,196 windows
#   Loaded 10/51 — 39,337 windows
#   Loaded 20/51 — 75,982 windows
#   Loaded 30/51 — 117,302 windows
#   Loaded 40/51 — 153,910 windows
#   Loaded 50/51 — 191,986 windows
#   Loaded 51/51 — 196,063 windows
#   Train 321,381 | Val 78,196 | Test 196,063
#   Parameters : 1,909,141
#   Epoch 01/30 | lr=2.80e-04 | loss=0.5999 | F1=0.7281 | κ=0.7323
# ...
