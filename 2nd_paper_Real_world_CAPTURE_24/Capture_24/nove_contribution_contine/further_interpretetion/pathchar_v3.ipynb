# %%
# !CUDA_VISIBLE_DEVICES=1 python without_architectural_components.py
# Out:
# Device : cuda
# GPU    : NVIDIA H800 PCIe
# ...
#   PatchHAR v2 — Ablation Latency Profiler
#   GPU runs: 500 × B=1 | CPU runs: 100 × B=1
#   Variants: baseline | ffn | self_attn | standard_transformer
# ...
#
#   ── Profiling  'baseline' ──
#      FLOPs … done
#      GPU latency (500 runs) … done
#      CPU latency (100 runs) … done
#      Throughput … done
#      Peak memory … done
#
#   ── Profiling  'ffn' ──
#      FLOPs … done
#      GPU latency (500 runs) … done
#      CPU latency (100 runs) … done
#      Throughput … done
#      Peak memory … done
#
#   ── Profiling  'self_attn' ──
#      FLOPs … done
#      GPU latency (500 runs) … done
#      CPU latency (100 runs) … done
#      Throughput … done
#      Peak memory … done
#
#   ── Profiling  'standard_transformer' ──
#      FLOPs … done
#      GPU latency (500 runs) … done
#      CPU latency (100 runs) … done
#      Throughput … done
#      Peak memory … done
#
# ════════════════════════════════════════════════════════════════════════
# ...
