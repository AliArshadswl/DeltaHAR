# %%
# !CUDA_VISIBLE_DEVICES=1 python real_world_ablations.py
# Out:
# Device : cuda
#    GPU : NVIDIA H800 PCIe  84.9 GB
# Classes (4): ['light', 'moderate-vigorous', 'sedentary', 'sleep']
# Participants — train=80, val=20, test=51
#
# ════════════════════════════════════════════════════════════════════════
#   HAR Directions Study  —  5 directions vs CGA-HybridHAR baseline
# ════════════════════════════════════════════════════════════════════════
#
# ── Loading data ─────────────────────────────────────────────────
#   Train subjects …
#   Loaded 80/80 subjects | 497302 windows
#   Val subjects …
#   Loaded 20/20 subjects | 120475 windows
#   Test subjects …
#   Loaded 51/51 subjects | 303891 windows
#   Windows — train=497,302  val=120,475  test=303,891
#   Building subject-stat map (for D5) …
#
# ════════════════════════════════════════════════════════════════════════
#   EXPERIMENT : D0_Baseline
#   CGA-HybridHAR baseline (21-token interleaved, symmetric CGA bias)
# ════════════════════════════════════════════════════════════════════════
# ...
