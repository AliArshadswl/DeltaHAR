# %%
# !CUDA_VISIBLE_DEVICES=2 python ADL_DeltaNet.py
# Out:
# Device: cuda
#   GPU: NVIDIA H800 PCIe
# ...
#   PatchHAR v2  --  ADL  --  LOGO CV
#   D_MODEL=768 | N_HEADS=12 | N_LAYERS=12 | N_EXPERTS=4
#   Window=300 samples @ 30 Hz | Patch=30 | Channels=3
#   Active contributions:
# ...
#
# Loading ADL dataset ...
#   Local load failed (Missing /home/ali/ADL/adl_30hz_clean/X.npy) — downloading from GitHub …
# ...
#   Downloaded ADL: X(635, 300, 3)
#   Classes (5): ['climb_stairs', 'drink_glass', 'getup_bed', 'pour_water', 'walk']
#     climb_stairs: 66
#     drink_glass: 105
#     getup_bed: 92
#     pour_water: 93
#     walk: 279
#   Participants: 7
#   Total windows: 635
#
# ...
#   FOLD 1/7  test=f1  val=f2
#   Windows  train:302  val:58  test:275
#   Parameters: 68,766,776
#     Ep 001/100 | F1=0.0649 | kappa=-0.0806
#     Ep 002/100 | F1=0.1551 | kappa=0.1070
#     Ep 003/100 | F1=0.2367 | kappa=0.1873
#     Ep 004/100 | F1=0.2399 | kappa=0.1347
#     Ep 005/100 | F1=0.2462 | kappa=0.1461
#     Ep 006/100 | F1=0.2815 | kappa=0.2279
# ...
