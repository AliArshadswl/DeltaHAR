# %%
# !CUDA_VISIBLE_DEVICES=2 python ADL_updated_parameters.py
# Out:
# Total ablation configurations: 11
#   D_MODEL=384                          D= 384 H=12 L=12 E=4
#   N_HEADS=2                            D= 768 H= 2 L=12 E=4
#   N_HEADS=4                            D= 768 H= 4 L=12 E=4
#   N_HEADS=6                            D= 768 H= 6 L=12 E=4
#   N_HEADS=8                            D= 768 H= 8 L=12 E=4
#   N_LAYERS=2                           D= 768 H=12 L= 2 E=4
#   N_LAYERS=4                           D= 768 H=12 L= 4 E=4
#   N_LAYERS=6                           D= 768 H=12 L= 6 E=4
#   N_LAYERS=8                           D= 768 H=12 L= 8 E=4
#   N_EXPERTS=5(=N_CLASSES)              D= 768 H=12 L=12 E=5
#   BASELINE                             D= 768 H=12 L=12 E=4
#
# Device: cuda
#   GPU: NVIDIA H800 PCIe
#
# ...
#   PatchHAR v2  --  ADL  --  Ablation Sweep
# ...
#
# Loading ADL dataset ...
#   Local load failed (Missing /home/ali/ADL/adl_30hz_clean/X.npy) — downloading ...
# ...
#   Downloaded ADL: X(635, 300, 3)
# ...
