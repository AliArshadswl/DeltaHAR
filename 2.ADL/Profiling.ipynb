# %%
# !CUDA_VISIBLE_DEVICES=2 python profiling_.py
# Out:
# Device: cuda
#   GPU: NVIDIA H800 PCIe
# ...
#   PatchHAR v2  --  ADL  --  BEST CONFIG  (N_LAYERS=8)
#   D=768 | H=12 | L=8 | E=4
# ...
#
# Loading ADL dataset ...
#   Local load failed (Missing /home/ali/ADL/adl_30hz_clean/X.npy) — downloading ...
# ...
#   Downloaded ADL: X(635, 300, 3)
#   Classes (5): ['climb_stairs', 'drink_glass', 'getup_bed', 'pour_water', 'walk']
#   Participants: 7
#   Total windows: 635
#
# ...
#   FOLD 1/7  test=f1  val=f2
#   train:302  val:58  test:275
#   Parameters: 54,549,556
#     Ep 001/100 | F1=0.0993 | kappa=0.0074
#     Ep 002/100 | F1=0.1965 | kappa=0.0843
#     Ep 003/100 | F1=0.3255 | kappa=0.1804
#     Ep 004/100 | F1=0.2725 | kappa=0.1166
#     Ep 005/100 | F1=0.3051 | kappa=0.3061
#     Ep 006/100 | F1=0.2794 | kappa=0.2730
#     Ep 007/100 | F1=0.3644 | kappa=0.3320
#     Ep 008/100 | F1=0.3548 | kappa=0.3040
#     Ep 009/100 | F1=0.3605 | kappa=0.3259
#     Ep 010/100 | F1=0.3549 | kappa=0.3237
#     Ep 011/100 | F1=0.3715 | kappa=0.3488
# ...
