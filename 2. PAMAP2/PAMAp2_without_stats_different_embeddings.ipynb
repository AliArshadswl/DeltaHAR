# %%
# !CUDA_VISIBLE_DEVICES=2 python PAMAp2_without_stats_different_embeddings.py
# Out:
# Device: cuda
#   GPU: NVIDIA H800 PCIe
# Loading PAMAP2 dataset ...
# Building windowed entries ...
#   Classes (8): ['ascending_stairs', 'descending_stairs', 'ironing', 'lying', 'sitting', 'standing', 'vacuum_cleaning', 'walking']
#   Subjects: [101, 102, 103, 104, 105, 106, 107, 108]
#   Total windows: 1427
#
# Active contributions:
#
# ...
#   FOLD 1/8  test=101  val=102  train=[103, 104, 105, 106, 107, 108]
#   Windows  train:1074  val:183  test:170
#   Parameters: 923,044
#     Ep 01/60 | F1=0.1283 | kappa=-0.0043
#     Ep 02/60 | F1=0.2597 | kappa=0.1912
#     Ep 03/60 | F1=0.2679 | kappa=0.2300
#     Ep 04/60 | F1=0.2438 | kappa=0.2152
#     Ep 05/60 | F1=0.2600 | kappa=0.2323
#     Ep 06/60 | F1=0.4039 | kappa=0.3604
#     Ep 07/60 | F1=0.3960 | kappa=0.3412
#     Ep 08/60 | F1=0.4583 | kappa=0.4175
#     Ep 09/60 | F1=0.4707 | kappa=0.4236
#     Ep 10/60 | F1=0.5453 | kappa=0.5027
#     Ep 11/60 | F1=0.5814 | kappa=0.5394
#     Ep 12/60 | F1=0.6101 | kappa=0.5763
# ...
